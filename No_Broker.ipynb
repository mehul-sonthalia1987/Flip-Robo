# %% [markdown]
# <a href="https://colab.research.google.com/github/mehul-sonthalia1987/Flip-Robo/blob/Web-Scraping/No_Broker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests
import re
url = 'https://www.nobroker.in/property/sale/bangalore/Electronic%20City?type=BHK4&searchParam=W3sibGF0IjoxMi44NDUyMTQ1LCJsb24iOjc3LjY2MDE2OTUsInBsYWNlSWQiOiJDaElKdy1GUWQ0cHNyanNSSGZkYXpnXzhYRW8iLCJwbGFjZU5hbWUiOiJFbGVjdHJvbmljIENpdHkifV0=&propertyAge=0&radius=2.0'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

house_title=[]
location=[]
Area=[]
Emi=[]
Price=[]
Temp2=[]
Temp1=[]
Temp3=[]

Title = soup.select('h2.heading-6.font-semi-bold.nb__1AShY')
for i in Title:
  house_title.append(i.text.replace('\n', ''))

Loc = soup.select('div.nb__35Ol7')
for i in Loc:
  location.append(i.text.replace('\n', ''))
location

Tempp = soup.select('div.font-semi-bold.heading-6')
for i in Tempp:
  Temp1.append(i.text.replace('\n', '').replace('â\x82¹',''))
len(Temp1)

Area = Temp1[0:30:3]
Emi = Temp1[1:30:3]
Price = Temp1[2:30:3]

import pandas as pd
NoBroker = pd.DataFrame({})
NoBroker['House Title']=house_title
NoBroker['Location']=location
NoBroker['Area ']=Area
NoBroker['Emi']=Emi
NoBroker['Price']=Price
NoBroker
# Out:
#                                          House Title  ...        Price
# 0  4 BHK In Independent House  For Sale  In Nagan...  ...      80 Lacs
# 1  4 BHK For Sale  In Daadys Garden In Electronic...  ...   1.5 Crores
# 2  4 BHK In Independent House  For Sale  In Sarja...  ...      70 Lacs
# 3          4 BHK Flat  For Sale  In Electronic City   ...      35 Lacs
# 4  4 BHK In Independent House  For Sale  In Elect...  ...   2.5 Crores
# 5  4 BHK In Independent House  For Sale  In Elect...  ...      90 Lacs
# 6  4 BHK Apartment  For Sale  In Gopalan Gardenia...  ...   1.1 Crores
# 7          4 BHK Flat  For Sale  In Electronic City   ...      50 Lacs
# 8  4 BHK Flat  For Sale  In Heena Enclave In Elec...  ...  1.25 Crores
# 9  4 BHK In Independent House  For Sale  In Anant...  ...      98 Lacs
#
# [10 rows x 5 columns]

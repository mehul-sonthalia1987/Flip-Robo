# %% [markdown]
# # Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location.
# You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
# !pip install selenium
# !pip install beautifulsoup4
import os,random, sys, time
#from urllib.parse import urlparse
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
browser = webdriver.Chrome('chromedriver.exe')

# %%
browser.get('https://www.naukri.com')
browser.maximize_window()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-156-9b180e2c20d8> in <module>
# ----> 1 browser.get('https://www.naukri.com')
#       2 browser.maximize_window()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ...

# %%
designation = browser.find_element_by_id('qsb-keyword-sugg')
designation.send_keys("Data Analyst")

# %%
location = browser.find_element_by_id('qsb-location-sugg')
location.send_keys("Bangalore")

# %%
search_button = browser.find_element_by_xpath("//button[@class='btn']")
search_button.click()

# %%
title = []
Title_list = browser.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')
Title_list
for i in Title_list:
  title.append(i.text.replace('\n', ''))
title

# %%
company = []
Company_list = browser.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')

for i in Company_list:
  company.append(i.text.replace('\n', ''))
company

# %%
exp = []
Exp_list = browser.find_elements_by_xpath('//span[@class="ellipsis fleft fs12 lh16"]')
for i in Exp_list:
  exp.append(i.text.replace('\n', ''))
exp[:3:]

# %%
year_exp=[]
year_exp=exp[0::3]

# %%
location_job=[]
location_job=exp[2::3]
location_job

# %%
import pandas as pd
Naukri = pd.DataFrame({})
Naukri['Job Title']=title[:10:]
Naukri['Company']=company[:10:]
Naukri['Exp Reqd ']=year_exp[:10:]
Naukri['Job Location']=location_job[:10:]

Naukri

# %% [markdown]
# # Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location.
# You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
browser = webdriver.Chrome('chromedriver.exe')

# %%
browser.get('https://www.naukri.com')
designation = browser.find_element_by_id('qsb-keyword-sugg')
designation.send_keys("Data Analyst")
location = browser.find_element_by_id('qsb-location-sugg')
location.send_keys("Bangalore")
search_button = browser.find_element_by_xpath("//button[@class='btn']")
search_button.click()
time.sleep(30)
title = []
Title_list = browser.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')
Title_list
for i in Title_list:
  title.append(i.text.replace('\n', ''))
company = []
Company_list = browser.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')

for i in Company_list:
  company.append(i.text.replace('\n', ''))
exp = []
Exp_list = browser.find_elements_by_xpath('//span[@class="ellipsis fleft fs12 lh16"]')
for i in Exp_list:
  exp.append(i.text.replace('\n', ''))
year_exp=[]
year_exp=exp[0::3]
location_job=[]
location_job=exp[2::3]

# %%
import pandas as pd
Naukri = pd.DataFrame({})
Naukri['Job Title']=title[:10:]
Naukri['Company']=company[:10:]
Naukri['Exp Reqd ']=year_exp[:10:]
Naukri['Job Location']=location_job[:10:]

Naukri

# %%
#3

# %%
title_url = []
for i in Title_list:
      title_url.append(i.get_attribute('href'))
title_url

# %%
desc_newline=[]
heading = []

# %%
for j in title_url[:10:]:
    browser.get(j)    
    
    try:
        Job_Desc = browser.find_element_by_xpath('//div[@class="dang-inner-html"]')
        desc_newline.append(Job_Desc.text.replace('\n', ''))
    except:
        Job_Desc = browser.find_element_by_xpath('//div[@class="nConfig_textblock "]')
        desc_newline.append(Job_Desc.text.replace('\n', ''))
      
    #Job_Heading= browser.find_element_by_xpath('//h1[@class="jd-header-title"]')
    #heading.append(Job_Heading.text.replace('\n', ''))

# %%
desc_newline

# %%
len(desc_newline)

# %%
Naukri_desc = Naukri
Naukri_desc['Description']=desc_newline[:10:]
Naukri_desc

# %% [markdown]
# # Q3: In this question you have to scrape data using the filters available on the webpage as shown below:
# You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results.
# You have to scrape the job-title, job-location, company name, experience required. The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs
# The task will be done as shown in the below steps:
# 1. first get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, and Companies” field.
# 3. Then click the search button.
# 4. Then apply the location filter and salary filter by checking the respective boxes
# 5. Then scrape the data for the first 10 jobs results you get.
# 6. Finally create a dataframe of the scraped data.
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
browser.get('https://www.naukri.com')

# %%
designation = browser.find_element_by_id('qsb-keyword-sugg')
designation.send_keys("Data Scientist")

# %%
location = browser.find_element_by_id('qsb-location-sugg')
location.send_keys("Bangalore")

# %%
search_button = browser.find_element_by_xpath("//button[@class='btn']")
search_button.click()

# %%
location_checkbox = browser.find_element_by_xpath("/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[2]/div[2]/div[4]/label/p/span[1]")
location_checkbox.click()

# %%
salary_checkbox = browser.find_element_by_xpath("/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[3]/div[2]/div[2]/label/p/span[1]")
salary_checkbox.click()

# %%
title2 = []
Title_list2 = browser.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')
Title_list2
for i in Title_list2:
  title2.append(i.text.replace('\n', ''))
title2

# %%
company2 = []
Company_list2 = browser.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')

for i in Company_list2:
  company2.append(i.text.replace('\n', ''))
company2

# %%
exp2 = []
Exp_list2 = browser.find_elements_by_xpath('//span[@class="ellipsis fleft fs12 lh16"]')
for i in Exp_list2:
  exp2.append(i.text.replace('\n', ''))
exp2

# %%
year_exp2=[]
year_exp2=exp2[0::3]
year_exp2

# %%
location_job2=[]
location_job2=exp2[2::3]
location_job2

# %%
import pandas as pd
Naukri_Checkbox = pd.DataFrame({})
Naukri_Checkbox['Job Title']=title2[:10:]
Naukri_Checkbox['Company']=company2[:10:]
Naukri_Checkbox['Exp Reqd ']=year_exp2[:10:]
Naukri_Checkbox['Job Location']=location_job2[:10:]

Naukri_Checkbox

# %% [markdown]
# # Q4: Scrape data of first 100 sunglasses listings on flipkart.com.
# You have to scrape four attributes:
# 1. Brand
# 2. Product Description
# 3. Price

# %%
browser = webdriver.Chrome('chromedriver.exe')

# %%
browser.get('https://www.flipkart.com')
#browser.maximize_window()

# %%
try:
    button = browser.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']")
    button.click()
except:
    pass

# %%
search_sunglass = browser.find_element_by_xpath("//input[@class='_3704LK']")
search_sunglass.send_keys("Sunglasses")
search_sunglass.send_keys(u'\ue007')

# %%
desc1 = []
for counter in range(0,4):
    description = browser.find_elements_by_xpath("//div[@class='_2B099V']")
    for i in description:
        desc1.append(i.text.split('\n'))
    #browser.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    time.sleep(10)
    next_button = browser.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]")
    next_button.click()
    time.sleep(15)
    counter=counter+1
print(len(desc1))
# Out:
# 120

# %%
brand = [i[0] for i in desc1]

# %%
description = [i[1] for i in desc1]

# %%
price = [i[2] for i in desc1]
# Out:
# ['₹359₹1,49976% off',
#  '₹349₹2,59986% off',
#  '₹193₹1,29885% off',
#  '₹243₹1,29981% off',
#  '₹287₹1,99885% off',
#  '₹220₹79972% off',
#  '₹227₹1,29982% off',
#  '₹359₹1,49976% off',
#  '₹261₹1,59983% off',
#  '₹155₹49968% off',
#  '₹148₹1,29988% off',
#  '₹355₹99964% off',
#  '₹348₹2,25684% off',
#  '₹649₹89927% off',
#  '₹229₹1,19980% off',
#  '₹287₹1,99885% off',
#  '₹144₹69979% off',
#  '₹467₹1,49968% off',
#  '₹209₹99979% off',
#  '₹291₹1,99985% off',
#  '₹649₹89927% off',
#  '₹879₹1,29932% off',
#  '₹224₹99977% off',
#  '₹449₹1,49970% off',
#  '₹575₹79928% off',
#  '₹192₹1,09982% off',
#  '₹152₹49969% off',
#  '₹164₹1,59989% off',
#  '₹359₹1,49976% off',
#  '₹255₹1,19978% off',
#  '₹175₹49964% off',
#  '₹165₹1,59989% off',
#  '₹939₹2,25058% off',
#  '₹200₹1,59987% off',
#  '₹225₹1,59985% off',
#  '₹898₹899',
#  '₹197₹1,29884% off',
#  '₹375₹1,29971% off',
#  '₹799₹99920% off',
#  '₹325₹1,66980% off',
#  '₹2,369₹4,70049% off',
#  '₹449₹1,49970% off',
# ...

# %%
prod_price = [i.split('₹', 2)[1] for i in price]

# %%
discount = [i[-7:] for i in price]
# Out:
# ['76% off',
#  '86% off',
#  '85% off',
#  '81% off',
#  '85% off',
#  '72% off',
#  '82% off',
#  '76% off',
#  '83% off',
#  '68% off',
#  '88% off',
#  '64% off',
#  '84% off',
#  '27% off',
#  '80% off',
#  '85% off',
#  '79% off',
#  '68% off',
#  '79% off',
#  '85% off',
#  '27% off',
#  '32% off',
#  '77% off',
#  '70% off',
#  '28% off',
#  '82% off',
#  '69% off',
#  '89% off',
#  '76% off',
#  '78% off',
#  '64% off',
#  '89% off',
#  '58% off',
#  '87% off',
#  '85% off',
#  '898₹899',
#  '84% off',
#  '71% off',
#  '20% off',
#  '80% off',
#  '49% off',
#  '70% off',
#  '74% off',
#  '55% off',
#  '66% off',
#  '76% off',
#  '9₹6,190',
#  '87% off',
#  '87% off',
#  '83% off',
#  '22% off',
#  '10% off',
#  '81% off',
#  '73% off',
#  '71% off',
#  '10% off',
#  '64% off',
#  '68% off',
#  '35% off',
#  '82% off',
#  '88% off',
#  '77% off',
#  '77% off',
#  '70% off',
#  '40% off',
#  '84% off',
#  '76% off',
#  '81% off',
#  '10% off',
#  '76% off',
#  '54% off',
# ...

# %%
print(len(brand), len(description), len(prod_price), len(disc1))
#disc1 = []
#discount = browser.find_elements_by_xpath("//div[@class='_3Ay6Sb']")
#for i in discount:
  #disc1.append(i.text)
#disc1
# Out:
# 120 120 120 118

# %%
Flipkart = pd.DataFrame()
Flipkart['Brand'] = brand[:100]
Flipkart['Description'] = description[:100]
Flipkart['Price'] = prod_price[:100]
Flipkart['Discount'] = disc1[:100]
Flipkart
# Out:
#          Brand                                        Description  Price  \
# 0    ROYAL SON                   Mirrored Aviator Sunglasses (55)    359
# 1       PIRASO            UV Protection Butterfly Sunglasses (65)    349
# 2   PHENOMENAL  UV Protection, Mirrored Round Sunglasses (Free...    193
# 3       SUNBEE  UV Protection, Polarized Wayfarer Sunglasses (...    243
# 4   PHENOMENAL  UV Protection, Mirrored Clubmaster Sunglasses ...    287
# ..         ...                                                ...    ...
# 95   ROYAL SON           UV Protection Over-sized Sunglasses (65)    699
# 96   ROYAL SON  UV Protection, Gradient Over-sized Sunglasses ...    664
# 97      GANSTA             UV Protection Wayfarer Sunglasses (54)    186
# 98       NuVew    UV Protection, Mirrored Aviator Sunglasses (57)    154
# 99     Ray-Ban                     Mirrored Round Sunglasses (55)  3,349
#
#    Discount
# 0   81% off
# 1   76% off
# 2   82% off
# 3   41% off
# 4   79% off
# ...

# %% [markdown]
# # Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone.
# You have to go the link: https://www.flipkart.com/apple-iphone-11-black-64-gb-includes- earpods-power- adapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKC TSVZAXUHGREPBFGI&marketplace.
# When you will open the above link you will reach to the below shown webpage
# As shown in the above page you have to scrape the tick marked attributes.These are:
# 1. Rating
# 2. Review summary
# 3. Full review
# 4. You have to scrape this data for first 100 reviews

# %%
browser = webdriver.Chrome('chromedriver.exe')

# %%
browser.get("https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKC")

# %%
review_button = browser.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div/div/div[5]/div/a/div")
review_button.click()

# %%
time.sleep(5)

# %%
ratings=[]
review_summary=[]
full_review = []
for counter in range(0,11):
    rating = browser.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
    for i in rating:
      ratings.append(i.text)
    summary = browser.find_elements_by_xpath("//p[@class='_2-N8zT']")
    for i in summary:
        review_summary.append(i.text)
    review = browser.find_elements_by_xpath("//div[@class='t-ZTKy']")
    for i in review:
        full_review.append(i.text.replace('\n','.'))
    time.sleep(5)
    next_button = browser.find_element_by_xpath("/html/body/div[1]/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[11]")
    next_button.click()
    time.sleep(15)
    counter=counter+1

# %%
print(len(ratings))
print(len(review_summary))
print(len(full_review))
# Out:
# 109
# 110
# 110

# %%
iphone = pd.DataFrame()
iphone['Ratings'] = ratings[:100]
iphone['Review Summary'] = review_summary[:100]
iphone['Full Review'] = full_review[:100]
iphone
# Out:
#    Ratings       Review Summary  \
# 0        5            Brilliant
# 1        5       Simply awesome
# 2        5  Best in the market!
# 3        5     Perfect product!
# 4        5    Worth every penny
# ..     ...                  ...
# 95       5            Fabulous!
# 96       5    Terrific purchase
# 97       5    Terrific purchase
# 98       5            Just wow!
# 99       5               Super!
#
#                                           Full Review
# 0   The Best Phone for the Money..The iPhone 11 of...
# 1   Really satisfied with the Product I received.....
# 2   Great iPhone very snappy experience as apple k...
# 3   Amazing phone with great cameras and better ba...
# 4   Previously I was using one plus 3t it was a gr...
# ..                                                ...
# 95  It’s very good battery life and display and vi...
# 96                                 Value for money 🖤🖤
# 97                                  Value for money 😍
# ...

# %% [markdown]
# # Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com andsearch for “sneakers” in the search field.
# You have to scrape 4 attributes of each sneaker:
# 1. Brand
# 2. Product Description
# 3. Price
# As shown in the below image, you have to scrape the tick marked attributes

# %%
browser = webdriver.Chrome('chromedriver.exe')
browser.get('https://www.flipkart.com')
try:
    button = browser.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']")
    button.click()
except:
    pass
search_sneakers = browser.find_element_by_xpath("//input[@class='_3704LK']")
search_sneakers.send_keys("Sneakers")
search_sneakers.send_keys(u'\ue007')

# %%
desc1 = []
for counter in range(0,4):
    description = browser.find_elements_by_xpath("//div[@class='_2B099V']")
    for i in description:
        desc1.append(i.text.split('\n'))
    #browser.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    time.sleep(10)
    next_button = browser.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]")
    next_button.click()
    time.sleep(15)
    counter=counter+1
print(len(desc1))
# Out:
# 120

# %%
desc1
# Out:
# [['ESSENCE', 'Sneakers For Men', '₹399₹99960% off'],
#  ['Kraasa', 'Series 7 Sneakers For Men', '₹444₹99955% off'],
#  ['Starlinc', 'Sneakers For Men', '₹237₹99976% off'],
#  ['Echor',
#   "Echor Men's Sneakers Fashion Lightweight Running Shoes ...",
#   '₹569₹1,49962% off',
#   'Free delivery'],
#  ['BIRDE',
#   'Combo Pack of 2 Casual Shoes Sneakers For Men',
#   '₹594₹1,49960% off',
#   'Free delivery'],
#  ['URBANBOX', 'STYLISH-WHITE-6 Sneakers For Men', '₹220₹49955% off'],
#  ['Robbie jones',
#   'Casual Sneakers Black Shoes For Men Sneakers For Men',
#   '₹451₹99954% off'],
#  ['Strollin', 'Sneakers For Men', '₹420₹99957% off'],
#  ['Zsyto',
#   'Sneakers For Men',
#   '₹328₹1,29974% off',
#   'Buy 2 items, save extra 5%'],
#  ['CLYMB', 'Sneakers For Men', '₹649₹1,49956% off', 'Free delivery'],
#  ['Robbie jones', 'Sneakers For Men', '₹499₹99950% off'],
#  ['Afreet',
#   'Sneakers For Men',
#   '₹489₹99951% off',
#   'Buy 2 items, save extra 5%'],
#  ['BRUTON',
# ...

# %%
brand = [i[0] for i in desc1]
# Out:
# ['ESSENCE',
#  'Kraasa',
#  'Starlinc',
#  'Echor',
#  'BIRDE',
#  'URBANBOX',
#  'Robbie jones',
#  'Strollin',
#  'Zsyto',
#  'CLYMB',
#  'Robbie jones',
#  'Afreet',
#  'BRUTON',
#  'DUNKASTON',
#  'Numenzo',
#  'Deals4you',
#  'India hub',
#  'RapidBox',
#  'BIRDE',
#  'GLOSSY LIFE',
#  'HRDK',
#  'Lee Won',
#  'WHITE WALKERS',
#  'T-ROCK',
#  'SPARX',
#  'Echor',
#  'believe',
#  'M7 By Metronaut',
#  'Kraasa',
#  'RODDICK SHOES',
#  'STRANGER BROTHERS',
#  'EEKEN',
#  'aadi',
#  'Airland',
#  'ASIAN',
#  'PUMA',
#  'LE GREEM',
#  'BRUTON',
#  'Bond Street By Red Tape',
#  'PEHANOSA',
#  'Chevit',
#  'Wenzel',
#  'Chevit',
#  'BIRDE',
#  'JACK & JONES',
#  'United Colors of Benetton',
#  "LEVI'S",
#  'PUMA',
#  'PUMA',
#  'India hub',
#  'obot',
#  'Cipramo',
#  'BRUTON',
#  'M7 By Metronaut',
#  'Trendmode',
#  'Cipramo',
#  'RED TAPE',
#  'Dicy',
#  'BRUTON',
#  'Cipramo',
#  'Next INN',
#  'KILLER',
#  'Robbie jones',
#  'PUMA',
#  'Skechers',
#  'PUMA',
#  'DUCATI',
# ...

# %%
description = [i[1] for i in desc1]
# Out:
# ['Sneakers For Men',
#  'Series 7 Sneakers For Men',
#  'Sneakers For Men',
#  "Echor Men's Sneakers Fashion Lightweight Running Shoes ...",
#  'Combo Pack of 2 Casual Shoes Sneakers For Men',
#  'STYLISH-WHITE-6 Sneakers For Men',
#  'Casual Sneakers Black Shoes For Men Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'Combo Pack Of 2 Latest Stylish Casual Shoes for Men Lac...',
#  'Sneakers For Men',
#  'White Sneaker For Men Sneakers For Men',
#  'Sneakers For Men',
#  'Luxury Fashionable casual sneaker shoes Sneakers For Me...',
#  'Sneakers For Men',
#  'Combo Pack of 2 Casual shoes Sneakers For Men',
#  'Sneakers For Men',
#  'Sneakers For Men',
#  'FASHION Sneakers For Men',
#  'Stylish & Trending Outdoor Walking Comfortable Sneakers...',
#  "Men's Stylish Sports Causal Sneakers shoes Sneakers For...",
#  'SM-322 Sneakers For Men',
# ...

# %%
price = [i[2] for i in desc1]
# Out:
# ['₹399₹99960% off',
#  '₹444₹99955% off',
#  '₹237₹99976% off',
#  '₹569₹1,49962% off',
#  '₹594₹1,49960% off',
#  '₹220₹49955% off',
#  '₹451₹99954% off',
#  '₹420₹99957% off',
#  '₹328₹1,29974% off',
#  '₹649₹1,49956% off',
#  '₹499₹99950% off',
#  '₹489₹99951% off',
#  '₹530₹2,49978% off',
#  '₹449₹1,49970% off',
#  '₹407₹1,29968% off',
#  '₹649₹1,99967% off',
#  '₹429₹1,99978% off',
#  '₹680₹99931% off',
#  '₹509₹1,49866% off',
#  '₹599₹2,99980% off',
#  '₹368₹99963% off',
#  '₹299₹49940% off',
#  '₹599₹1,19850% off',
#  '₹699₹99930% off',
#  '₹891₹1,04915% off',
#  '₹498₹1,49966% off',
#  '₹424₹99957% off',
#  '₹729₹1,49951% off',
#  '₹449₹99955% off',
#  '₹474₹99952% off',
#  '₹449₹99955% off',
#  '₹879₹1,59945% off',
#  '₹399₹1,99980% off',
#  '₹190₹49961% off',
#  '₹649₹1,29950% off',
#  '₹1,749₹3,49950% off',
#  '₹426₹99957% off',
#  '₹536₹2,49978% off',
#  '₹1,259₹4,19970% off',
#  '₹439₹99956% off',
#  '₹446₹99855% off',
#  '₹499₹99950% off',
#  '₹581₹1,49861% off',
# ...

# %%
prod_price = [i.split('₹', 2)[1] for i in price]
# Out:
# ['399',
#  '444',
#  '237',
#  '569',
#  '594',
#  '220',
#  '451',
#  '420',
#  '328',
#  '649',
#  '499',
#  '489',
#  '530',
#  '449',
#  '407',
#  '649',
#  '429',
#  '680',
#  '509',
#  '599',
#  '368',
#  '299',
#  '599',
#  '699',
#  '891',
#  '498',
#  '424',
#  '729',
#  '449',
#  '474',
#  '449',
#  '879',
#  '399',
#  '190',
#  '649',
#  '1,749',
#  '426',
#  '536',
#  '1,259',
#  '439',
#  '446',
#  '499',
#  '581',
#  '423',
#  '1,048',
#  '1,664',
#  '1,199',
#  '3,999',
#  '3,499',
#  '449',
#  '549',
#  '999',
#  '447',
#  '729',
#  '369',
#  '999',
#  '1,011',
#  '392',
#  '447',
#  '999',
#  '499',
#  '899',
#  '474',
#  '3,599',
#  '3,359',
#  '1,999',
#  '1,439',
#  '535',
#  '166',
#  '525',
#  '2,995',
#  '999',
#  '1,096',
#  '536',
#  '474',
#  '3,299',
#  '524',
#  '439',
#  '479',
#  '2,209',
#  '449',
#  '259',
#  '979',
#  '879',
#  '729',
#  '499',
#  '698',
#  '3,149',
#  '1,749',
#  '2,877',
#  '407',
#  '999',
#  '979',
#  '459',
#  '5,399',
#  '989',
# ...

# %%
discount = [i[-7:] for i in price]
# Out:
# ['60% off',
#  '55% off',
#  '76% off',
#  '62% off',
#  '60% off',
#  '55% off',
#  '54% off',
#  '57% off',
#  '74% off',
#  '56% off',
#  '50% off',
#  '51% off',
#  '78% off',
#  '70% off',
#  '68% off',
#  '67% off',
#  '78% off',
#  '31% off',
#  '66% off',
#  '80% off',
#  '63% off',
#  '40% off',
#  '50% off',
#  '30% off',
#  '15% off',
#  '66% off',
#  '57% off',
#  '51% off',
#  '55% off',
#  '52% off',
#  '55% off',
#  '45% off',
#  '80% off',
#  '61% off',
#  '50% off',
#  '50% off',
#  '57% off',
#  '78% off',
#  '70% off',
#  '56% off',
#  '55% off',
#  '50% off',
#  '61% off',
#  '57% off',
#  '65% off',
#  '55% off',
#  '70% off',
#  '50% off',
#  '50% off',
#  '77% off',
#  '63% off',
#  '33% off',
#  '85% off',
#  '51% off',
#  '47% off',
#  '33% off',
#  '78% off',
#  '34% off',
#  '82% off',
#  '33% off',
#  '61% off',
#  '70% off',
#  '52% off',
#  '55% off',
#  '52% off',
#  '50% off',
#  '60% off',
#  '46% off',
#  '66% off',
#  '47% off',
#  '₹2,995',
# ...

# %%
print(len(brand), len(description), len(prod_price), len(disc1))
# Out:
# 120 120 120 118

# %%
Flipkart = pd.DataFrame()
Flipkart['Brand'] = brand[:100]
Flipkart['Description'] = description[:100]
Flipkart['Price'] = prod_price[:100]
Flipkart['Discount'] = disc1[:100]
Flipkart
# Out:
#              Brand                                        Description  Price  \
# 0          ESSENCE                                   Sneakers For Men    399
# 1           Kraasa                          Series 7 Sneakers For Men    444
# 2         Starlinc                                   Sneakers For Men    237
# 3            Echor  Echor Men's Sneakers Fashion Lightweight Runni...    569
# 4            BIRDE      Combo Pack of 2 Casual Shoes Sneakers For Men    594
# ..             ...                                                ...    ...
# 95        RED TAPE                                   Sneakers For Men    989
# 96      GOOD MINAR  Fashion and Stylish Designer shoes with Printe...    447
# 97  FLYING MACHINE                                   Sneakers For Men    698
# 98         Noztile        Casual Party Wear Shoe Men Sneakers For Men    499
# 99            PUMA                             Rigel Sneakers For Men  1,256
#
#    Discount
# 0   81% off
# 1   76% off
# ...

# %% [markdown]
# # Q7: Go to the link - https://www.myntra.com/shoes
# Set Price filter to “Rs. 7149 to Rs. 14099 ” , Color filter to “Black”, as shown inthe below image.
# And then scrape First 100 shoes data you get.
# The data should include “Brand” of the shoes , Short Shoe description, price of the shoe as shown in the below image.

# %%
browser = webdriver.Chrome('chromedriver.exe')
browser.get('https://www.myntra.com/shoes')
time.sleep(10)

# %%
#color_checkbox = browser.find_element_by_xpath("/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[6]/ul/li[1]/label/div")
browser.execute_script("arguments[0].click();", WebDriverWait(browser, 30).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[6]/ul/li[1]/label/div"))))
#color_checkbox.click()

#The above mentioned code will wait until the element is clickable

# %%
#price_checkbox = browser.find_element_by_xpath("/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label/div")
browser.execute_script("arguments[0].click();", WebDriverWait(browser, 30).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label/div"))))
#price_checkbox.click()

# %%
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
desc1 = []
for counter in range(0,3):    
    time.sleep(5)
    if counter==0:
        time.sleep(45) #sleep timer given as the element was not being loaded and throwing an exception of StaleElement
    description = browser.find_elements_by_xpath("//div[@class='product-productMetaInfo']")
    for i in description:
        desc1.append(i.text.split('\n'))
        
    browser.execute_script("arguments[0].click();", WebDriverWait(browser, 30).until(EC.element_to_be_clickable((By.XPATH, "//a[@rel='next']"))))
    counter=counter+1
print(len(desc1))
# Out:
# 150

# %%
#desc1

# %%
brand = [i[0] for i in desc1]

# %%
description = [i[1] for i in desc1]

# %%
price = [i[2] for i in desc1]
prod_price = [i.split('Rs.', 2)[1] for i in price]

# %%
print(len(brand), len(description), len(prod_price))
# Out:
# 150 150 150

# %%
import pandas as pd
Myntra = pd.DataFrame()
Myntra['Brand'] = brand[:100]
Myntra['Description'] = description[:100]
Myntra['Price'] = prod_price[:100]
Myntra
# Out:
#            Brand                          Description   Price
# 0           Puma            Men Magnify Nitro Running    7799
# 1        Saint G            Men Mid-Top Chelsea Boots   10500
# 2       Skechers       Men GO RUN RIDE 9 RunningShoes    8799
# 3        Bugatti                    Men Running Shoes    7999
# 4           Xtep                    Men Running Shoes    7699
# ..           ...                                  ...     ...
# 95  Hush Puppies    Men Solid Leather Formal Slip-Ons    8999
# 96  Hush Puppies            Men Solid Formal Slip-Ons    8999
# 97       Saint G           Women Leather Heeled Boots   12325
# 98       Saint G  Textured Leather Block Heeled Boots    9265
# 99          Nike            Women Air Max 90 Sneakers   10995
#
# [100 rows x 3 columns]

# %% [markdown]
# # Q8: Go to webpage https://www.amazon.in/
# Enter “Laptop” in the search field and then click the search icon.
# Then set CPU Type filter to “Intel Core i7” and “Intel Core i9”:
# After setting the filters scrape first 10 laptops data. You have to scrape 3 attributesfor each laptop:
# 1. Title
# 2. Ratings
# 3. Price

# %%
browser = webdriver.Chrome('chromedriver.exe')
browser.get('https://www.amazon.in/')
time.sleep(5)

# %%
search_laptop = browser.find_element_by_xpath("//input[@id='twotabsearchtextbox']")
search_laptop.send_keys("laptop")
search_laptop.send_keys(u'\ue007')

# %%
try:
    browser.execute_script("arguments[0].click();", WebDriverWait(browser, 30).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/span/div/div/div[5]/ul[3]/li[12]/span/a/div/label/i"))))
except:
    browser.execute_script("arguments[0].click();", WebDriverWait(browser, 30).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[5]/ul[3]/li[11]/span/a/div/label/i"))))
#browser.execute_script("arguments[0].click();", WebDriverWait(browser, 30).until(EC.element_to_be_clickable((By.XPATH, "/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/span/div/div/div[5]/ul[3]/li[11]/span/a/div/label/i"))))

# %%
titles = browser.find_elements_by_xpath("//a[@class='a-link-normal s-link-style a-text-normal']")
title = []
for i in titles:
    title.append(i.text)
# Out:
# 30

# %%
prices = browser.find_elements_by_xpath("//span[@class='a-price']")
price = []
for i in prices:
    price.append(i.text)
# Out:
# ['₹94,999',
#  '₹90,999',
#  '₹59,990',
#  '₹84,990',
#  '₹49,990',
#  '₹89,490',
#  '₹96,990',
#  '₹88,990',
#  '₹79,990',
#  '₹1,14,990',
#  '₹88,890',
#  '₹77,999',
#  '₹89,990',
#  '₹69,990',
#  '₹77,999',
#  '₹1,10,000',
#  '₹87,490',
#  '₹1,06,799',
#  '₹97,920',
#  '₹94,999',
#  '₹84,990',
#  '₹36,898',
#  '₹99,990',
#  '₹1,02,490',
#  '₹59,990',
#  '₹86,990',
#  '₹91,414',
#  '₹54,999',
#  '₹89,490',
#  '₹49,990']

# %%
import pandas as pd
laptop = pd.DataFrame()
laptop['Brand'] = title[:10]
laptop['Description'] = price[:10]
laptop
# Out:
#                                                Brand Description
# 0  LG Gram 17-inches Ultra-Light Intel Evo 11th G...     ₹94,999
# 1  LG Gram 16-inches Ultra-Light Intel Evo 11th G...     ₹90,999
# 2  ASUS VivoBook 14 (2021), 14-inch (35.56 cms) F...     ₹59,990
# 3  HP Pavilion x360 11th Gen Intel Core i7-16GB R...     ₹84,990
# 4  Mi Notebook Horizon Edition 14 Intel Core i7-1...     ₹49,990
# 5  Acer Nitro 5 AN515-57 Gaming Laptop | Intel Co...     ₹89,490
# 6  ASUS TUF Gaming F15 (2021) 15.6-inch (39.62 cm...     ₹96,990
# 7  HP Pavilion 13, 11th Gen Intel Core i7, 13.3-i...     ₹88,990
# 8  Lenovo ThinkBook 13s Intel 11th Gen Core i7 13...     ₹79,990
# 9  ASUS TUF Gaming F15 (2021) 15.6-inch (39.62 cm...   ₹1,14,990

# %%
#unable to extract ratings, please guide

# %% [markdown]
# # Q9: Write a python program to scrape data for first 10 job results for Data Scientist Designation in Noida location.
# You have to scrape company name, No. of days ago when job was posted, Rating of the company. This task will be done in following steps:
# 1. First get the webpage https://www.ambitionbox.com/
# 2. Click on the Job option as shown in the image
# 3. After reaching to the next webpage, In place of “Search by Designations, Companies, Skills” enter “Data Scientist” and click on search button.
# 4. You will reach to the following web page click on location and in place of “Search location” enter “Noida” and select location “Noida”.
# 5. Then scrape the data for the first 10 jobs results you get on the above shown page.
# 6. Finally create a dataframe of the scraped data.

# %%
browser = webdriver.Chrome('chromedriver.exe')
browser.get('https://www.ambitionbox.com/')
time.sleep(5)

# %%
jobs = browser.find_element_by_xpath("//a[@class='link jobs']")
jobs.click()

# %%
designation = browser.find_element_by_xpath("//input[@class='input tt-input']")
designation.send_keys("Data Scientist")

# %%
search = browser.find_element_by_xpath("//button[@class='ab_btn search-btn round']")
search.click()
time.sleep(10)

# %%
location = browser.find_element_by_xpath("//div[@title='Location']")
location.click()

# %%
location_noida = browser.find_element_by_xpath("//input[@placeholder='Search locations']")
location_noida.send_keys("Noida")
time.sleep(5)

# %%
#browser.execute_script("arguments[0].click();", WebDriverWait(browser, 30).until(EC.element_to_be_clickable((By.XPATH, "//input[@id='location_Noida"))))
label_noida = browser.find_element_by_xpath("//input[@id='location_Noida']")
label_noida.click()

# %%
more_jobs = browser.find_element_by_xpath("//button[@class='ab_btn load-more-btn invert']")
more_jobs.click()
time.sleep(10)

# %%
company = browser.find_elements_by_xpath("//p[@class='company body-medium']")
company_name = []
for i in company:
    company_name.append(i.text)

# %%
company_name
# Out:
# ['J.P. Morgan Services India Private Limited',
#  'IBM India Pvt. Limited',
#  'IBM India Pvt. Limited',
#  'JP Morgan Chase',
#  'IBM India Pvt. Limited',
#  'IBM India Pvt. Limited',
#  'IBM India Pvt. Limited',
#  'IBM India Pvt. Limited',
#  'IBM India Pvt. Limited',
#  'IBM India Pvt. Limited',
#  'Optum Global Solutions (India) Private Limited',
#  'EY GDS',
#  'Ameriprise Financial',
#  'Jubilant Foodworks Limited',
#  'Zyoin',
#  'CHT Sapiense',
#  'Paytm',
#  'CHT Sapiense',
#  'GI Group',
#  'GI Group']

# %%
other_info = browser.find_elements_by_xpath("//div[@class='other-info']")
info = []
for i in other_info:
    info.append(i.text.split('\n'))

# %%
days = [i[-1] for i in info]
days_ago = [i.split('·', 2)[0] for i in days]

# %%
rate = browser.find_elements_by_xpath("//div[@class='rating-wrapper']")

# %%
rating = []
for i in rate:
    rating.append(i.text.split('\n'))
rating[3:]
# Out:
# [['4.1', 'based on 2.3k Reviews'],
#  ['4.1', '(2.3k Reviews)'],
#  ['4.1', '(11k Reviews)'],
#  ['4.1', '(11k Reviews)'],
#  ['4.1', '(2.3k Reviews)'],
#  ['4.1', '(11k Reviews)'],
#  ['4.1', '(11k Reviews)'],
#  ['4.1', '(11k Reviews)'],
#  ['4.1', '(11k Reviews)'],
#  ['4.1', '(11k Reviews)'],
#  ['4.1', '(11k Reviews)'],
#  ['4.1', '(1.5k Reviews)'],
#  ['3.7', '(3.8k Reviews)'],
#  ['4.0', '(272 Reviews)'],
#  ['3.9', '(504 Reviews)'],
#  ['4.1', '(66 Reviews)'],
#  ['3.8', '(105 Reviews)'],
#  ['3.7', '(2.7k Reviews)'],
#  ['3.8', '(105 Reviews)'],
#  ['4.1', '(70 Reviews)'],
#  ['4.1', '(70 Reviews)']]

# %%
ratings = [i[0] for i in rating]
ratings = ratings[3:]

# %%
import pandas as pd
ambtionbox = pd.DataFrame()
ambtionbox['Company Name'] = company_name[:10]
ambtionbox['Days Ago'] = days_ago[:10]
ambtionbox['Ratings'] = ratings[:10]
ambtionbox
# Out:
#                                  Company Name Days Ago Ratings
# 0  J.P. Morgan Services India Private Limited   6d ago     4.1
# 1                      IBM India Pvt. Limited   6d ago     4.1
# 2                      IBM India Pvt. Limited   6d ago     4.1
# 3                             JP Morgan Chase   6d ago     4.1
# 4                      IBM India Pvt. Limited   6d ago     4.1
# 5                      IBM India Pvt. Limited   6d ago     4.1
# 6                      IBM India Pvt. Limited   6d ago     4.1
# 7                      IBM India Pvt. Limited   6d ago     4.1
# 8                      IBM India Pvt. Limited   6d ago     4.1
# 9                      IBM India Pvt. Limited   6d ago     4.1

# %% [markdown]
# # Q10: Write a python program to scrape the salary data for Data Scientist designation.
# You have to scrape Company name, Number of salaries, Average salary, Minsalary, Max Salary. The above task will be, done as shown in the below steps:
# 1. First get the webpage https://www.ambitionbox.com/
# 2. Click on the salaries option as shown in the image.
# 3. After reaching to the following webpage, In place of “Search Job Profile” enters “Data Scientist” and then click on “Data Scientist”.
# You
# You have to scrape the data ticked in the above image.
# 4. Scrape the data for the first 10 companies. Scrape the company name, total salary record, average salary, minimum salary, maximum salary, experience required.
# 5. Store the data in a dataframe.
# Note: All the steps required during scraping should be done through code only and not manually.

# %%
browser = webdriver.Chrome('chromedriver.exe')
browser.get('https://www.ambitionbox.com/')
time.sleep(5)

# %%
salaries = browser.find_element_by_xpath("//a[@class='link salaries']")
salaries.click()

# %%
designation = browser.find_element_by_xpath("//input[@class='component-input tt-input']")
designation.send_keys("Data Scientist")
time.sleep(5)

# %%
data_scientist = browser.find_element_by_xpath("/html/body/div/div/div/div[2]/div/div/div/div[1]/span/div/div[2]/div[2]/div[2]/div/p")
data_scientist.click()

# %%
search_button = browser.find_element_by_xpath("//button[@class='ab_btn search-btn round component-search-btn']")
search_button.click()

# %%
result = browser.find_elements_by_xpath("//div[@class='result-row']")
results = []
for i in result:
    results.append(i.text.split('\n'))

# %%
company_name = [i[0] for i in results]

# %%
salary_record = [i[1] for i in results]

# %%
average_salary = [i[4] for i in results]

# %%
min_salary = [i[5] for i in results]

# %%
max_salary = [i[6] for i in results]

# %%
exp_reqd = [i[3] for i in results]

# %%
import pandas as pd
Ambition_Box = pd.DataFrame()
Ambition_Box['Company Name'] = company_name
Ambition_Box['Total Salary Record'] = salary_record
Ambition_Box['Average Salary'] = average_salary
Ambition_Box['Minimum Salary'] = min_salary
Ambition_Box['Maximum Salary'] = max_salary
Ambition_Box['Experience Required'] = exp_reqd
Ambition_Box
# Out:
#         Company Name Total Salary Record Average Salary Minimum Salary  \
# 0                TCS      (662 Salaries)         ₹ 7.5L         ₹ 4.5L
# 1          Accenture      (400 Salaries)        ₹ 12.0L         ₹ 5.5L
# 2                IBM      (311 Salaries)        ₹ 12.1L         ₹ 5.1L
# 3          Cognizant      (261 Salaries)         ₹ 9.4L         ₹ 5.0L
# 4          Capgemini      (246 Salaries)         ₹ 8.3L         ₹ 4.6L
# 5      Tech Mahindra      (195 Salaries)         ₹ 7.7L         ₹ 4.2L
# 6            Infosys      (186 Salaries)         ₹ 8.8L         ₹ 4.5L
# 7              Wipro      (174 Salaries)         ₹ 9.4L         ₹ 4.4L
# 8           Ericsson      (128 Salaries)        ₹ 13.5L         ₹ 5.3L
# 9  Fractal Analytics      (125 Salaries)        ₹ 15.2L         ₹ 9.5L
#
#   Maximum Salary Experience Required
# 0        ₹ 15.0L         2-9 yrs exp
# 1        ₹ 22.0L         2-9 yrs exp
# 2        ₹ 24.0L        2-12 yrs exp
# ...
